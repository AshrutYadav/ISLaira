# %%
! pip install pose-format
# Out:
# ...
#   Using cached scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
# Using cached scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.1/39.1 MB 2.3 MB/s  0:00:17m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pose-format] [pose-format]-utils]
# ...

# %%
from pose_format import Pose
with open("UPof0XUr0kU_d.pose", "rb") as f:
    data_buffer = f.read()

# Load the pose object
pose = Pose.read(data_buffer)

# Access the raw skeletal data (NumPy array)
numpy_data = pose.body.data

# Access the confidence scores for the landmarks
confidence_measure = pose.body.confidence

# %%
pose.body.data
# Out:
# masked_array(
#   data=[[[[149.53363037109375, 83.00415802001953, -0.9191831350326538],
#           [159.4354705810547, 71.0931625366211, -0.8396210074424744],
#           [163.447509765625, 71.55908203125, -0.8399605751037598],
#           ...,
#           [-18.822629928588867, 121.27578735351562,
#            -0.2967393696308136],
#           [46.42662811279297, 199.549560546875, -0.014897480607032776],
#           [-6.086018085479736, 106.90425109863281, -0.5892346501350403]]],
#
#
#         [[[150.8927764892578, 83.00494384765625, -1.0101197957992554],
#           [159.7194061279297, 71.11495208740234, -0.9306313991546631],
#           [163.77261352539062, 71.57477569580078, -0.9308550953865051],
#           ...,
#           [-23.646657943725586, 126.47221374511719,
#            -0.2711622416973114],
#           [39.31938171386719, 220.8516387939453, 0.020243624225258827],
#           [-8.607532501220703, 122.89887237548828, -0.5395614504814148]]],
#
#
# ...

# %%
pose.body.confidence
# Out:
# array([[[9.9999237e-01, 9.9998593e-01, 9.9998772e-01, ...,
#          3.6482021e-04, 1.2404367e-04, 3.7377974e-04]],
#
#        [[9.9999142e-01, 9.9998462e-01, 9.9998605e-01, ...,
#          3.7289050e-04, 1.2724541e-04, 3.7127302e-04]],
#
#        [[9.9999112e-01, 9.9998450e-01, 9.9998564e-01, ...,
#          4.1261286e-04, 1.4843777e-04, 3.9983841e-04]],
#
#        ...,
#
#        [[9.9999207e-01, 9.9998760e-01, 9.9998778e-01, ...,
#          3.3716645e-04, 2.1403904e-04, 3.7789912e-04]],
#
#        [[9.9999231e-01, 9.9998808e-01, 9.9998814e-01, ...,
#          3.2663901e-04, 2.2363510e-04, 3.9023257e-04]],
#
#        [[9.9999291e-01, 9.9998897e-01, 9.9998903e-01, ...,
#          3.1755152e-04, 2.3651680e-04, 4.1659398e-04]]], dtype=float32)
